# %%
# insert an image
from IPython.display import Image
Image(url= "/imageExample.PNG")
# Out:
# <img src="/imageExample.PNG"/>

# %%
# write an image
import requests
data = requests.get('http://localhost:8889/view/Desktop/DL/imageExample.PNG').content
with open('image.png', 'wb') as file:
     file.write(data)

# %%
# insert local imaage
from IPython.display import Image
Image(filename = 'imageExample.PNG', width=600, height=600)

# %%
# insert web imaage
from IPython.display import Image
Image( 'https://img2018.cnblogs.com/blog/1235684/201903/1235684-20190306202339677-1771970027.png', width=600, height=600)
